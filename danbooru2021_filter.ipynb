# %%
import pandas as pd

# %%
df = pd.read_json('danbooru2021\posts000000000011.json', orient='records', lines=True)
df
# Out:
#                                        tag_string_general  \
# 0       1girl blush chihaya_(clothing) flute instrumen...
# 1       1girl blonde_hair hair_ribbon hairband long_ha...
# 2       1girl clothes_lift greyscale monochrome pantie...
# 3       1girl arms_behind_back blonde_hair blue_eyes b...
# 4       2girls black_dress blonde_hair blue_eyes bonne...
# ...                                                   ...
# 416879  1boy 1girl :d bath bathing bathroom bathtub bl...
# 416880  1girl arm_up armpits blue_eyes blush breasts b...
# 416881  1girl arms_behind_back bangs black_hair blue_e...
# 416882  1girl against_glass anus ass ass_on_glass ass_...
# 416883  6+girls abyssal_ship ahoge armpits blush bunny...
#
#         has_visible_children  has_large  tag_count_meta  bit_flags  \
# 0                      False        1.0               0          0
# 1                      False        0.0               0          0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416884 entries, 0 to 416883
# Data columns (total 48 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   tag_string_general      416884 non-null  object
#  1   has_visible_children    416884 non-null  bool
#  2   has_large               415948 non-null  float64
#  3   tag_count_meta          416884 non-null  int64
#  4   bit_flags               416884 non-null  int64
#  5   has_active_children     416884 non-null  bool
#  6   preview_file_url        406581 non-null  object
#  7   image_width             416884 non-null  int64
#  8   updated_at              416884 non-null  datetime64[ns, UTC]
#  9   tag_string_artist       416884 non-null  object
#  10  tag_count               416884 non-null  int64
#  11  is_status_locked        416884 non-null  bool
#  12  is_pending              416884 non-null  bool
#  13  file_size               416884 non-null  int64
# ...

# %%
df_reduced = df.iloc[:100000]
df_reduced
# df_reduced['timestamp'] = pd.to_datetime(df_reduced['updated_at'])
# Out:
#                                       tag_string_general  \
# 0      1girl blush chihaya_(clothing) flute instrumen...
# 1      1girl blonde_hair hair_ribbon hairband long_ha...
# 2      1girl clothes_lift greyscale monochrome pantie...
# 3      1girl arms_behind_back blonde_hair blue_eyes b...
# 4      2girls black_dress blonde_hair blue_eyes bonne...
# ...                                                  ...
# 99995  1girl :d blush bow choker dated dress eyelashe...
# 99996  3girls comic genderswap genderswap_(mtf) greys...
# 99997  2boys children's_book doctor male_focus multip...
# 99998  1girl angry black_hair blue_eyes constricted_p...
# 99999  2girls closed_eyes crying geass greyscale hair...
#
#        has_visible_children  has_large  tag_count_meta  bit_flags  \
# 0                     False        1.0               0          0
# 1                     False        0.0               0          0
# 2                     False        0.0               0          0
# ...

# %%
def filter_row(row, min_tags=15, min_year=2018):
    if row['is_deleted']:
        return False
    if row['is_banned']:
        return False
    if row['created_at'].year < min_year:
        return False
    if len(row['tag_string'].split(' ')) <= min_tags:
        return False
    return True

# %%
df_filtered = df_reduced[df_reduced.apply(filter_row,axis=1)]
df_filtered
# Out:
#                                       tag_string_general  \
# 2362   1girl breasts closed_mouth gloves horns large_...
# 2363   1boy adjusting_hair bow bowtie brown_eyes chil...
# 2364   1boy ahoge belt blue_hair blue_pupils closed_m...
# 2366   2girls :d ahoge arm_up bangs black_shirt black...
# 2367   1boy ^_^ ahoge blush closed_eyes gloves goodby...
# ...                                                  ...
# 99974  1boy 1girl bag bangs beach blue_dress blue_hai...
# 99977  2boys abs ahegao anal bar_censor bara beard ce...
# 99984  2girls 4koma blush bow catching closed_eyes co...
# 99985  1other aircraft airplane androgynous clear_sky...
# 99986  4girls bow comic greyscale hair_bow hand_on_ow...
#
#        has_visible_children  has_large  tag_count_meta  bit_flags  \
# 2362                  False        0.0               0          2
# 2363                  False        0.0               0          2
# 2364                  False        1.0               0          2
# ...

# %%
df_filtered_sampled = df_filtered.iloc[:150].reset_index(drop=True)
df_filtered_sampled
# Out:
#                                     tag_string_general  has_visible_children  \
# 0    1girl breasts closed_mouth gloves horns large_...                 False
# 1    1boy adjusting_hair bow bowtie brown_eyes chil...                 False
# 2    1boy ahoge belt blue_hair blue_pupils closed_m...                 False
# 3    2girls :d ahoge arm_up bangs black_shirt black...                 False
# 4    1boy ^_^ ahoge blush closed_eyes gloves goodby...                 False
# ..                                                 ...                   ...
# 145  1boy artist_name bangs black_shirt collarbone ...                 False
# 146  1boy bags_under_eyes black_hair black_headwear...                 False
# 147  1boy 5girls aqua_hair ass bangs black_hair blu...                 False
# 148  1girl :o bangs black_shirt boots brown_footwea...                 False
# 149  1girl bangs blue_eyes blush breasts chibi eyeb...                 False
#
# ...

# %%
df_filtered_sampled['tag_count'].hist()
# Out:
# <Axes: >

# %%
df_filtered['tag_count'].hist()
# Out:
# <Axes: >

# %%
json_str = df_filtered_sampled.to_json(orient='records')
with open('test_data.json', 'w') as f:
    f.write(json_str)

# %%
test_set = pd.read_json('bruh.json',orient='records')
test_set
# Out:
#                                     tag_string_general  has_visible_children  \
# 0    1girl blush chihaya_(clothing) flute instrumen...                 False
# 1    1girl clothes_lift greyscale monochrome pantie...                 False
# 2    2girls black_dress blonde_hair blue_eyes bonne...                 False
# 3    1girl 3d animal_ears brown_hair fishnet_legwea...                 False
# 4    1girl :d beret blush brown_gloves full-face_bl...                 False
# ..                                                 ...                   ...
# 145  1boy 1girl blue_sailor_collar blue_skirt brown...                 False
# 146  1girl bangs belt blue_sailor_collar blue_skirt...                 False
# 147  1boy earrings gae_bolg_(fate) greyscale jewelr...                 False
# 148  1girl bangs blue_eyes blue_hair blue_sailor_co...                 False
# 149  1girl asymmetrical_hair flower from_side hair_...                 False
#
# ...

# %%
test_set[['prompt_string', 'caption_string']]
# Out:
#                                          prompt_string  \
# 0    Reply with a concise description of an artwork...
# 1    Reply with a concise description of an artwork...
# 2    Reply with a highly condensed run on sentence ...
# 3    Reply with a concise description of an artwork...
# 4    Reply with a concise description of an artwork...
# ..                                                 ...
# 145  Reply with a highly condensed run on sentence ...
# 146  Reply with a concise description of an artwork...
# 147  Reply with a highly condensed run on sentence ...
# 148  Reply with a concise description of an artwork...
# 149  Reply with a concise description of an artwork...
#
#                                         caption_string
# 0    The artwork features a blushing girl named Tsu...
# 1    The artwork features the character Al Azif fro...
# 2    Vermisste's artist rendition of Shinku Suigint...
# 3    The artwork features the character Suzumiya Ha...
# ...

# %%
test_set['created_at'].hist()
# Out:
# <Axes: >

# %%
df['created_at'].year.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df['created_at'].year.value_counts()
#
# File c:\Users\panta\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'year'
